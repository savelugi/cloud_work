# %%
from visualization import *
from network_graph import *



csv_file_name = '/Users/ebenbot/Documents/University/cloud_work/saves/dynamic/20241109124941_usa/20241109124941_usa.csv'
df_results = pd.read_csv(csv_file_name, comment='#')
mod_cols = ['tick', 'model_type', 'num_players', 'nr_of_active_game_servers', 'nr_of_player_migrations', 'nr_of_server_migrations', 'nr_of_players_moved',
            'average_player_to_server_delay', 'min_player_to_server_delay', 'max_player_to_server_delay', 'average_player_to_player_delay', 'min_player_to_player_delay',
            'max_player_to_player_delay', 'qoe_score']
mod_data = df_results[mod_cols]

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=mod_data, x='tick', y='average_player_to_player_delay', label='Server activity')

# Inverting X axis
invert = False
if invert:
    plt.gca().invert_xaxis()

plt.xlabel('Tick')
plt.ylabel('Number of Active Game Servers')
plt.title('Server Activity Over Time')
plt.legend()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=mod_data, x='tick', y='num_players', label='Server activity')

# Inverting X axis
invert = False
if invert:
    plt.gca().invert_xaxis()

plt.xlabel('Tick')
plt.ylabel('')
plt.title('')
plt.legend()

# %%
player = 'P1'

print(int(player[1:]))
# Out:
# 1
